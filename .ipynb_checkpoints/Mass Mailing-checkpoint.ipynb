# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas as pd
import time
import re

# %% [markdown]
# valid email checking function

# %%
def is_valid_email(email):
    email = email.strip()
    pattern = r'^[\w\.-]+@[\w\.-]+$'
    return re.match(pattern, email) is not None

# %% [markdown]
# user data

# %%
sender_email = "abhinavs0410@gmail.com"
password = "zramxuynjaeiwgfs"
subject = "Application for internship as Software Developer"
with open("msgg.txt", "r") as file:
    message = file.read()
    
smtp_server = "smtp.gmail.com"
smtp_port = 587

# %%
def sendmail():
    context = smtplib.SMTP(smtp_server, smtp_port)
    context.starttls()
    context.login(sender_email, password)

    df_read = pd.read_csv('maildone.csv')
    read_recipients = list(df_read['Email'])
    i = 0
    
    for recipient in recipients: 
        if(i > 50):
            break
            
        if recipient in read_recipients:
            continue
        
        i+=1
        if is_valid_email(recipient) == False:
            read_recipients.append(recipient)
            print(i, recipient, "Not Done")
            continue
        
        msg = MIMEMultipart()
        msg['From'] = sender_email
        msg['Subject'] = subject
        msg.attach(MIMEText(message, 'html'))
        msg['To'] = recipient
        print(i, recipient)
          
        context.sendmail(sender_email, recipient, msg.as_string())
        read_recipients.append(recipient)
        
        df_read = pd.DataFrame(read_recipients, columns=['Email'])
        df_read.to_csv('maildone.csv')
    
    context.quit()
    df_read = pd.DataFrame(read_recipients, columns=['Email'])
    df_read.to_csv('maildone.csv')
    print("Total Mailed:", i)
    return i

# %% [markdown]
# Reciepient Data

# %%
recipients = ["b21175@students.iitmandi.ac.in",
              "Milanhrdept@arysontechnologies.com",
              "hrindia@ptcit.com",
              "gvemuganti@tataunistore.com",
              "eradi.ramya@aujas.com",
              "roopa.g@aujas.com",
              "mrunal_t@sigma-byte.com",
              
              ]

# %%
file_names = ["emails1.csv",
              "email_addresses.csv"]

df = pd.read_csv(file_names[1])
recipients = list(df['Email'])

len(recipients)
# Out:
# 1879

# %%
x = int(input("ENTER VALUE: "))
if(x != 101):
    print("Wrong Value")

else:
    print("Starting")

    total_mailed = 0
    
    for _ in range(1000):
        val = sendmail()
        total_mailed += val
        print("\nDone:", _ + 1, "\n")
        
        if(val == 0):
            print("\nCOMPLETED")
            break
            
        time.sleep(20)
# Out:
# ENTER VALUE: 101
# Starting
# 1 shavee.s@algonomy.com
# 2 sheena.malhotra@netsmartz.com
# 3 sbiswas@cognitusconsulting.com
# 4 sheetal.deshmukh@contractpodai.com
# 5 sheetal@gameopedia.com
# 6 sheetal.pote@saviantconsulting.com
# 7 sheetal.sawant@aeriestechnology.com
# 8 shefali@dynproindia.com
# 9 shelton.b@cynetsystems.com
# 10 shenoj.balaraman@rebit.org.in
# 11 shhweta@cashkaro.com
# 12 shikha.dhillon@decimaltech.com
# 13 shikha@rahinfotech.com
# 14 shikha.gupta@tatacommunications.com
# 15 shikha.gupta@winwire.com
# 16 shikha.kothari@klearnow.com
# 17 shikha.soni@franconnect.com
# 18 shilpam@codeforce.com
# 19 shilpa.malhotra@mindtickle.com
# 20 shilpa.reddy@aeriestechnology.com
# 21 sshukla@anaqua.com
# 22 shilpa.tungikar@infrasofttech.com
# 23 shilpi.saklani@metro-gsc.in
# 24 shilpi@netomi.com
# 25 shilpikar@petroit.com
# 26 shipra.lavania@wundermanthompson.com
# 27 shipra.pandit@juspay.in
# 28 shipra.rai@niveussolutions.com
# 29 shirin.varghese@sugarboxnetworks.com
# 30 shirish.bavdekar@3ds.com
# 31 shishir.singh@milkbasket.com
# 32 shiva@winwire.com
# 33 shiva@comakeit.com
# 34 sshukla@tanishasystems.com
# 35 shivangi@sensehq.com
# 36 shivangi@gatewaytechnolabs.com
# 37 shivani.chaturvedi@mjunction.in
# 38 shivani@virtualheight.com
# 39 khanna.shivani@digitate.com
# 40 shivani@eminds.ai
# 41 shivani@acpl.com
# 42 shoaib.ahmed@nuware.com
# 43 shobana@hubilo.com
# 44 first@softenger.com
# 45 shraddha@digite.com
# 46 shradha.sule@northgateps.com
# 47 shravan@sigmoid.com
# 48 shreeja.santosh@lrn.com
# 49 shreelipta.mishra@blujaysolutions.com
# 50 shreesh_katti@bluerose-tech.com
# 51 shreyasi@valuepitch.com
# Total Mailed: 51
#
# Done: 1
#
# 1 shrikant@agileglobalsolutions.com
# 2 shruti.bhargava@netcomlearning.com
# 3 shruti.gandhi@moolya.com
# 4 shruti.malhotra@orange.com
# 5 shubham@kastechssg.com
# 6 shubha.menon@soltius.co.id
# 7 shubhada.kale@atyeti.com
# 8 shubhamkatiyar@ameyo.com
# 9 bose@precisiontechcorp.com
# 10 shubhra.narang@c-zentrix.com
# 11 shuchi.nijhawan@ekaplus.com
# 12 shweta@valuecoders.com
# 13 shweta@desteksolutions.com
# 14 smurthy@aurusinc.com
# 15 shwetasetia@ayoconnect.id
# 16 shweta@signitysolutions.com
# 17 shwetha@rudderstack.com
# 18 shyam.warrier@neudesic.com
# 19 shyama@lesoft.com
# 20 shyamili.satyendran@tarento.com
# 21 shyni.k@netcon.in
# 22 siddharth.balakrishnan@crmit.com
# 23 siddharth.gaur@credencys.com
# 24 sijimolj@aditiconsulting.com
# 25 simran.kalra@avataar.me
# 26 simran.nair@hexagon.com
# 27 sprabakar@sciohealthanalytics.com
# 28 sindhuja.parthasarathy@mindtickle.com
# 29 sini@ittdigital.com
# 30 sp@calliduscloud.com
# 31 sirisree.dayanand@aggne.com
# 32 sitaram.kuruganti@quadrantresource.com
# 33 sivasankar.r@provintl.com
# 34 smita.narkar@infinite-uptime.com
# 35 smitha@cybersecit.net
# 36 smitha.pradeep@aptos.com
# 37 smitha.s@truglobal.com
# 38 smitha.sajo@applexus.com
# 39 smitha@alchemysolutions.asia
# 40 sneha@merklescience.com
# 41 sneha@virinchi.com
# 42 sneha@tavisca.com
# 43 snehdeep.ambarkar@cientra.com
# 44 snigdha@saavn.com
# 45 solution.head@solutionanalysts.com
# 46 sgupta@encoress.com
# 47 somesh.sharma@infostride.com
# 48 somya.babu@gramtarang.in
# 49 sonal.srivastava@mobilecoderz.com
# 50 sonal.upadhyay@thepsi.com
# 51 sonali.bhave@infrasofttech.com
# Total Mailed: 51
#
# Done: 2
#
# 1 sonalip@selectsourceintl.com
# 2 hr@cyntexa.com
# 3 sonali.titus@intelegencia.com
# 4 sonam.dwivedi@transunion.com
# 5 soni@intellolabs.com
# 6 sonia.gahlot@fivesdigital.com
# 7 sonia@klausit.com
# 8 sophronia@reshamandi.com
# 9 soumya@zoondia.in
# 10 soumya@impress.ai
# 11 soundarya.murugaiyan@cts.co
# 12 sourabh.jain@fiserv.com
# 13 s.rai@drishti.com
# 14 sourabha.ravi@valuepointsystems.com
# 15 sourik.s@frontizo.in
# 16 sowmya@probeinformation.com
# 17 sowmya@ibhubs.co
# 18 sree@straviso.com
# 19 sree.umamaheswari@impigertech.com
# 20 sreeja.sreedharan@skuad.io
# 21 sreeparna.samanta@urbanladder.com
# 22 sreepriya@eagleview.co.in
# 23 sreeram@qualizeal.com
# 24 smohanty@primusglobal.com
# 25 sreevalli.k@sstech.us
# 26 sreevidhya.shashi@itorizon.com
# 27 sputta@aztecsoftware.com
# 28 sridevi@sedintechnologies.com
# 29 sridevi.v@jeevantechnologies.com
# 30 sridhar.barige@jsw.in
# 31 sridhar.kotha@gupshup.io
# 32 sridhar.m@fluentgrid.com
# 33 sridhar.srinivasan@boardex.com
# 34 srikanthb@techpointsolutions.com
# 35 srikanth.e@mergenit.com
# 36 srikanth.sathyanarayana@komprise.com
# 37 srikrishna@fugoservices.com
# 38 srinath.g@nexval.com
# 39 srini@technogeninc.com
# 40 srinidhi.d@keka.com
# 41 srinivas@collaboratesolutions.com
# 42 srinivas.polaris@polarismanagement.com
# 43 srinivas.talampuranam@inspirage.com
# 44 ssundaram@tetrasoft.us
# 45 srivathsan.mg@kumaran.com
# 46 srividhya.deshpande@springml.com
# 47 stephen@eoxvantage.com
# 48 suba@geval6.com
# 49 subbarao.c@softpath.net
# 50 sdas@edrinfo.com
# 51 subhashbv@macomsolutions.com
# Total Mailed: 51
#
# Done: 3
#
# 1 subhash.chandra@silverlinecrm.com
# 2 subramanian.adaikalam@sumtotalsystems.com
# 3 subramanian@logisofttechinc.com
# 4 sponnusamy@aequor.com
# 5 subramanya@reshamandi.com
# 6 subrina@flobiz.in
# 7 mathew@techautocons.com
# 8 sucheta.ukidve@mindstix.com
# 9 sudeep.chakkingal@ssitsol.com
# 10 sudeep.luthra@orange.com
# 11 sudhaav@buddi.ai
# 12 sudhakar@noblesoft.com
# 13 sudhindra.sarnobat@isourceinfosystems.com
# 14 sudhir.b@aeriestechnology.com
# 15 sudhir.salve@searshc.com
# 16 sudhir.shinde@nielseniq.com
# 17 suguna.rajaram@ymedialabs.com
# 18 suhasinir@amzetta.com
# 19 sujathag@celcomsolutions.com
# 20 sujatha.v@oneglobesystems.com
# 21 sujee@crayondata.com
# 22 sujeet.rao@diverselynx.com
# 23 sujit.jiandani@aethereus.com
# 24 sukeshni.tulasi@napierhealthcare.com
# 25 sukhpreet.sandhu@itilite.com
# 26 sulabh.daigavhane@truminds.com
# 27 sumalatha.d@ritesoftware.com
# 28 suman.bhattacharjee@webskitters.com
# 29 suman.kitawat@fivesplash.in
# 30 suman.mukherjee@ultimatesolutions.in
# 31 sumarani.y@ekaplus.com
# 32 sumit.k@nrconsultingservice.com
# 33 sumit.midha@intellolabs.com
# 34 sumukhi.jairam@nttdata.com
# 35 sunaina@u3infotech.com
# 36 sunandha@telliant.net
# 37 sundeep.dasa@valgenesis.com
# 38 sundeep.pandey@puresoftware.com
# 39 sunder.rangarajan@businessintegra.com
# 40 sunetra@hiverhq.com
# 41 skapoor@milcorp.com
# 42 sunils2@innov.in
# 43 sunila_jaikumar@edgeverve.com
# 44 sunit.kanoi@ag-technologies.com
# 45 sdave@relsci.com
# 46 sunithas@affluentgs.com
# 47 sunny.chavan@mediaagility.com
# 48 sunny.shroff@unitech-rio.com.br
# 49 sunny.walia@axeno.co
# 50 ssekhar@utopiainc.com
# 51 supreeth.gudla@euclidinnovations.com
# Total Mailed: 51
#
# Done: 4
#
# 1 supriya.a@ecolabdigitalcenter.in
# 2 hr.mumbai@konverge.co.in
# 3 supriya.lulla@doyen.co.in
# 4 supriya.shonu@deeptek.ai
# 5 surabhi.sharma@se2.com
# 6 suraj.shylaja@g10x.com
# 7 surajeet@stockedge.com
# 8 surbhi.gupta@enquero.com
# 9 surbhi.sinha@kapture.cx
# 10 suresh.aade@foodhub.com
# 11 sureshc@vuram.com
# 12 suresh@truetechsolutions.in
# 13 suresh@aspirenxt.com
# 14 suresh.n@wrenchsolutions.com
# 15 sureshkumar.tedlapu@criticalriver.com
# 16 tsuresh@kutirtech.com
# 17 surinderc@damcogroup.com
# 18 suriya.kumar@kumaran.com
# 19 surojitc@interrait.com
# 20 suruchi.handa@azilen.com
# 21 skhosla@contecglobal.com
# 22 susan.dsilva@aujas.com
# 23 susan@kissflow.com
# 24 susheelk@ironsystems.com
# 25 sushil.kumar@expediteinc.com
# 26 sushmita.aduri@teklink.com
# 27 susmita.kaushik@blazeclan.com
# 28 suva.dasgupta@theblueflamelabs.com
# 29 suvarna_f@sigma-byte.com
# 30 suvro.karmakar@ubique-systems.com
# 31 suzanna.tapala@ankercloud.com
# 32 sveta.shenoy@technoidentity.com
# 33 swagato.sengupta@areteanstech.com
# 34 swaminathan.srinivasan@transactcampus.com
# 35 swapna.jaladi@savantis.com
# 36 swapna.krishna@theoptimum.net
# 37 swapna@avestacs.com
# 38 snag@tataunistore.com
# 39 swapnil.bhoskar@pragmasys.in
# 40 swapnil.pilkhane@aqmtechnologies.com
# 41 swapnil.trikane@irisbusiness.com
# 42 swaroop.gokhale@mediaagility.com
# ---------------------------------------------------------------------------
# SMTPSenderRefused                         Traceback (most recent call last)
# Cell In [24], line 11
#       8 total_mailed = 0
#      10 for _ in range(1000):
# ---> 11     val = sendmail()
#      12     total_mailed += val
#      13     print("\nDone:", _ + 1, "\n")
#
# Cell In [20], line 30, in sendmail()
#      27 msg['To'] = recipient
#      28 print(i, recipient)
# ---> 30 context.sendmail(sender_email, recipient, msg.as_string())
#      31 read_recipients.append(recipient)
#      33 df_read = pd.DataFrame(read_recipients, columns=['Email'])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\smtplib.py:887, in SMTP.sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     885     else:
#     886         self._rset()
# --> 887     raise SMTPSenderRefused(code, resp, from_addr)
#     888 senderrs = {}
#     889 if isinstance(to_addrs, str):
#
# SMTPSenderRefused: (421, b'4.7.0 Try again later, closing connection. (MAIL)\n4.7.0  Learn more at\n4.7.0  https://support.google.com/a/answer/3221692 i13-20020a65484d000000b00578afd8e012sm997154pgs.92 - gsmtp', 'abhinavs0410@gmail.com')

# %% [markdown]
# Code Done Here

# %%
context = smtplib.SMTP(smtp_server, smtp_port)
context.starttls()
context.login(sender_email, password)

temp_email = "careers@kanrad.com"
msg = MIMEMultipart()
msg['From'] = sender_email
msg['Subject'] = subject
msg.attach(MIMEText(message, 'html'))
msg['To'] = temp_email

context.sendmail(sender_email, temp_email, msg.as_string())
context.quit()
# Out:
# (221,
#  b'2.0.0 closing connection a6-20020aa78e86000000b006b4a5569694sm2688689pfr.83 - gsmtp')
