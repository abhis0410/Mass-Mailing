# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
url = "https://dokumen.tips/documents/all-companies-hr-email-ids-55844b4b070ad.html"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, height=device-height, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots">
# <title>(DOC) All Companies HR Email Ids - DOKUMEN.TIPS</title>
# <!-- Meta info -->
# <meta content="careershrdinfosys, campus0405spectrumconsultants, hrmabrookservices, satherenaissance, agowdainformatica, indiajobstforceinc, dreamcareerszensar, chavansurvik, amatgcpamat, haridasiflexsolutions, adialcatel, vasavduttacelstream, annysoftgmail, dmimindscapeindia, recruitingprapansol, harshalianlagehro, ssamalubicsindia, avivabangalore247customer, aliintelob, boononmobile, sseninterwoven, raointel, hpinoidea, shaijuzmcit, mspwipro, doulegeometricsoftware, resumeindiainformatica, tarunacs, soniasmirandatata, idccvsmicrosoft, download All Companies HR Email Ids" name="keywords">
# ...

# %%
from bs4 import BeautifulSoup

# Parse the HTML content
soup = BeautifulSoup(response.content, "html.parser")

# Find all div elements with the specified style attribute
divs = soup.find_all("div", style="background-color: white; color: #141823; font-family: Helvetica, Arial, 'lucida grande', tahoma, verdana, arial, sans-serif; font-size: 14px; line-height: 19.3199996948242px; margin-bottom: 6px; margin-top: 6px;")

company_names = []
email_addresses = []

# Extract company names and email addresses
for div in divs:
    company_name, email = div.text.split(" --- ")
    company_names.append(company_name.strip())
    email_addresses.append(email.strip())

# Create a DataFrame
data = {
    'Email': email_addresses
}
df = pd.DataFrame(data)

# %%
file_path = "temp.txt"

# %%
with open(file_path, 'r', encoding='utf-8') as file:
    email_text = file.read()

# %%
email_text = email_text.replace('\n', ',')
email_text = email_text.replace(' ', ',')

email_addresses = email_text.split(',')

# Remove any leading or trailing spaces
email_addresses = [email.strip() for email in email_addresses]

# %%
while '' in email_addresses:
    email_addresses.remove('')

# %%
email_addresses
# Out:
# ['padmashree.sv@sonata-software.com',
#  'flexisys@rediffmail.com',
#  'Leelavathy.CK@kmgin.com',
#  'shakunthala.bhat@wipro.com',
#  'hr.blr@bluechipsw.com',
#  'jobs@captronicsystems.com',
#  'bangalore.careers@tcgivega.com',
#  'jobs@exateam.com',
#  'viji.g@ivtlinfoview.co.jp',
#  'careers@omnesysindia.com',
#  'roopashree.bn@sonata-software.com',
#  'kavitha.u@sonata-software.com',
#  'Athikho.Kayina@gxs.com',
#  'Anitha.Krishnappa@igate.com',
#  'jyothi@recruitbeyond.com',
#  'svasudevan@aivea.com',
#  'Ashik.Swamy@iflexsolutions.com',
#  'munazeera@symbiosisnetwork.com',
#  'raheem.ahmed@ge.com',
#  'raghu@esparkinfotech.com',
#  'joseph.lukose@relianceada.com',
#  'sherin@xsysys.com',
#  'vksawant@tpc.co.in',
#  'abdal.nizar@xansa.com',
#  'abdal.nizar@xansa.com',
#  'accenture@merittrac.com',
#  'admin@kazstroyindia.com',
#  'agowda@informatica.com',
#  'ajay.p@novell.com',
#  'Ajith.abraham@hp.com',
#  'amdocsblr@samoorna.com',
#  'Amjad@whirltechndia.com',
# ...

# %%
df = pd.DataFrame({"Email" : email_addresses})
df.to_csv("email_list_2.csv")
